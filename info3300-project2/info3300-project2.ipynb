# %%
import numpy as np
import pandas as pd

# %%
hdi = pd.read_csv('HDI.csv')
hdi.head()
# Out:
#                 Country  Human Development Index (2000)  \
# 0           Afghanistan                           0.335
# 1                Angola                           0.375
# 2               Albania                           0.677
# 3               Andorra                           0.818
# 4  United Arab Emirates                           0.796
#
#    Human Development Index (2001)  Human Development Index (2000).1  \
# 0                           0.337                             0.335
# 1                           0.386                             0.375
# 2                           0.684                             0.677
# 3                           0.825                             0.818
# 4                           0.800                             0.796
#
#    Human Development Index (2002)  Human Development Index (2003)  \
# 0                           0.362                           0.376
# 1                           0.403                           0.420
# ...

# %%
hdi = hdi[['Country','Human Development Index (2000)', 'Human Development Index (2001)', 'Human Development Index (2000)', 'Human Development Index (2002)', 'Human Development Index (2003)','Human Development Index (2004)', 'Human Development Index (2005)','Human Development Index (2006)', 'Human Development Index (2007)',
          'Human Development Index (2008)','Human Development Index (2009)', 'Human Development Index (2010)', 'Human Development Index (2011)', 'Human Development Index (2012)', 'Human Development Index (2013)', 'Human Development Index (2014)', 'Human Development Index (2015)', 'Human Development Index (2016)', 'Human Development Index (2017)', 'Human Development Index (2018)', 'Human Development Index (2019)', 'Human Development Index (2020)', 'Human Development Index (2021)']]

# %%
hdi.head()
# Out:
#                 Country  Human Development Index (2000)  \
# 0           Afghanistan                           0.335
# 1                Angola                           0.375
# 2               Albania                           0.677
# 3               Andorra                           0.818
# 4  United Arab Emirates                           0.796
#
#    Human Development Index (2001)  Human Development Index (2000)  \
# 0                           0.337                           0.335
# 1                           0.386                           0.375
# 2                           0.684                           0.677
# 3                           0.825                           0.818
# 4                           0.800                           0.796
#
#    Human Development Index (2002)  Human Development Index (2003)  \
# 0                           0.362                           0.376
# 1                           0.403                           0.420
# ...

# %%
hdi.fillna(0)
hdi.to_csv('hdi.csv',index=False)
